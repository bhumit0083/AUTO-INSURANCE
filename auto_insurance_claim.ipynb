# %% [markdown]
# <a href="https://colab.research.google.com/gist/Jaymangrolia21/c1e9adda1315e6abeef44e5027583206/auto_insurance_claim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Load the data**

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls'/content/drive/MyDrive/DAB103-Project'
# Out:
# Auto_insurance_claim.csv  Auto_insurance_claim.ipynb

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
insurance_data = pd.read_csv("/content/drive/MyDrive/DAB103-Project/Auto_insurance_claim.csv") 
insurance_data
# Out:
#      months_as_customer  age  policy_number     policy_bind_date policy_state  \
# 0                   328   48         521585  2014-10-17 00:00:00           OH
# 1                   228   42         342868  2006-06-27 00:00:00           IN
# 2                   134   29         687698  2000-09-06 00:00:00           OH
# 3                   256   41         227811  1990-05-25 00:00:00           IL
# 4                   228   44         367455  2014-06-06 00:00:00           IL
# ..                  ...  ...            ...                  ...          ...
# 995                   3   38         941851  1991-07-16 00:00:00           OH
# 996                 285   41         186934  2014-01-05 00:00:00           IL
# 997                 130   34         918516  2003-02-17 00:00:00           OH
# 998                 458   62         533940  2011-11-18 00:00:00           IL
# 999                 456   60         556080  1996-11-11 00:00:00           OH
#
# ...

# %%
insurance_data.head()
# Out:
#    months_as_customer  age  policy_number     policy_bind_date policy_state  \
# 0                 328   48         521585  2014-10-17 00:00:00           OH
# 1                 228   42         342868  2006-06-27 00:00:00           IN
# 2                 134   29         687698  2000-09-06 00:00:00           OH
# 3                 256   41         227811  1990-05-25 00:00:00           IL
# 4                 228   44         367455  2014-06-06 00:00:00           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# ...

# %%
insurance_data.tail()
# Out:
#      months_as_customer  age  policy_number     policy_bind_date policy_state  \
# 995                   3   38         941851  1991-07-16 00:00:00           OH
# 996                 285   41         186934  2014-01-05 00:00:00           IL
# 997                 130   34         918516  2003-02-17 00:00:00           OH
# 998                 458   62         533940  2011-11-18 00:00:00           IL
# 999                 456   60         556080  1996-11-11 00:00:00           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
# ...

# %%
help(sns)
# Out:
# Help on package seaborn:
#
# NAME
#     seaborn - # Import seaborn objects
#
# PACKAGE CONTENTS
#     _core
#     _decorators
#     _docstrings
#     _statistics
#     _testing
#     algorithms
#     apionly
#     axisgrid
#     categorical
#     cm
#     colors (package)
#     conftest
#     distributions
#     external (package)
#     linearmodels
#     matrix
#     miscplot
#     palettes
#     rcmod
#     regression
#     relational
#     tests (package)
#     timeseries
#     utils
#     widgets
#
# DATA
#     crayons = {'Almond': '#EFDECD', 'Antique Brass': '#CD9575', 'Apricot':...
#     xkcd_rgb = {'acid green': '#8ffe09', 'adobe': '#bd6c48', 'algae': '#54...
#
# VERSION
#     0.11.2
#
# FILE
#     /usr/local/lib/python3.7/dist-packages/seaborn/__init__.py

# %%
insurance_data.sample(5)
# Out:
#      months_as_customer  age  policy_number     policy_bind_date policy_state  \
# 543                  37   25         421092  2003-03-04 00:00:00           OH
# 515                 284   48         168260  1991-03-01 00:00:00           OH
# 303                 267   40         426708  2009-10-09 00:00:00           IL
# 805                 290   42         135400  2014-01-20 00:00:00           IN
# 352                  65   26         360770  2005-09-21 00:00:00           IN
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 543    100/300               1000                1221.17               0
# 515    250/500               1000                1168.80               0
# 303    250/500                500                1155.53         5000000
# 805   500/1000                500                 989.97               0
# 352    100/300                500                1285.03         3000000
#
# ...

# %%
insurance_data.shape
# Out:
# (1000, 39)

# %%
insurance_data.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
insurance_data.describe(include='O')
# Out:
#            policy_bind_date policy_state policy_csl insured_sex  \
# count                  1000         1000       1000        1000
# unique                  951            3          3           2
# top     2006-01-01 00:00:00           OH    250/500      FEMALE
# freq                      3          352        351         537
#
#        insured_education_level insured_occupation insured_hobbies  \
# count                     1000               1000            1000
# unique                       7                 14              20
# top                         JD  machine-op-inspct         reading
# freq                       161                 93              64
#
#        insured_relationship        incident_date            incident_type  \
# count                  1000                 1000                     1000
# unique                    6                   60                        4
# top               own-child  2015-02-02 00:00:00  Multi-vehicle Collision
# ...

# %%
insurance_data.info()
#there is null value in police_report_available column, we will work on that in cleaning part,
#in incident it shows time in 00:00 so, we do not need it
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
insurance_data.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# ...

# %%
insurance_data.duplicated().any()
# Out:
# False

# %%
insurance_data.drop_duplicates(inplace=True)

# %%
insurance_data.duplicated().sum()
# Out:
# 0

# %%
insurance_data.values[0]
# Out:
# array([328, 48, 521585, '2014-10-17 00:00:00', 'OH', '250/500', 1000,
#        1406.91, 0, 466132, 'MALE', 'MD', 'craft-repair', 'sleeping',
#        'husband', 53300, 0, '2015-01-25 00:00:00',
#        'Single Vehicle Collision', 'Side Collision', 'Major Damage',
#        'Police', 'SC', 'Columbus', '9935 4th Drive', 5, 1, 'YES', 1, 2,
#        'YES', 71610, 6510, 13020, 52080, 'Saab', '92x', 2004, 'Y'],
#       dtype=object)

# %%
insurance_data.incident_type.unique()
# Out:
# array(['Single Vehicle Collision', 'Vehicle Theft',
#        'Multi-vehicle Collision', 'Parked Car'], dtype=object)

# %%
insurance_data.auto_make.unique()
# Out:
# array(['Saab', 'Mercedes', 'Dodge', 'Chevrolet', 'Accura', 'Nissan',
#        'Audi', 'Toyota', 'Ford', 'Suburu', 'BMW', 'Jeep', 'Honda',
#        'Volkswagen'], dtype=object)

# %%
insurance_data.auto_make.value_counts()
# Out:
# Saab          80
# Dodge         80
# Suburu        80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: auto_make, dtype: int64

# %%
insurance_data.corr()
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.922098       0.057555
# age                                    0.922098  1.000000       0.059413
# policy_number                          0.057555  0.059413       1.000000
# policy_deductable                      0.026807  0.029188      -0.006738
# policy_annual_premium                  0.005018  0.014404       0.022566
# umbrella_limit                         0.015498  0.018126       0.008968
# insured_zip                            0.017895  0.025604       0.007083
# capital-gains                          0.006399 -0.007075       0.009802
# capital-loss                           0.020209  0.007368      -0.005669
# incident_hour_of_the_day               0.070639  0.087161       0.000113
# number_of_vehicles_involved            0.014736  0.022102       0.013432
# bodily_injuries                       -0.010162 -0.015679      -0.004558
# ...

# %%
#plot the histogram to see the distribution of the point data.
sns.displot(insurance_data, x="age")

# %%
sns.heatmap(insurance_data.corr())

# %%
plt.figure(figsize=(20,10))
plt.title("Check Outlier with boxplot for total claim amount")
insurance_data.boxplot(column=['total_claim_amount']);

# %%
plt.figure(figsize=[22,10])
sns.displot(insurance_data['total_claim_amount'])
plt.title('Total Claim Amount Distribution Plot')
# Out:
# Text(0.5, 1.0, 'Total Claim Amount Distribution Plot')

# %%
insurance_data['incident_type'].value_counts(normalize=True).plot.pie(startangle=30, autopct='%1.1f%%')
plt.title('Incident Types')
plt.show()

# %%
sns.countplot(insurance_data['insured_sex'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
insurance_data['fraud_reported'].value_counts(normalize=True).plot.pie(startangle=90, autopct='%1.1f%%')
plt.show()
